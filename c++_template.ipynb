# %% [markdown]
# **C++**

# %%
# %%writefile main.cpp
#
# #include <iostream>
#
# int main() {
#     std::cout << "Hello, GColab!" << std::endl;
#     return 0;
# }
# Out:
# Writing main.cpp

# %%
# %%script bash
#
# g++ main.cpp -std=c++11
# ./a.out
# Out:
# Hello, GColab!
